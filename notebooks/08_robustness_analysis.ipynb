# %%
from src.reporting import RobustnessReporter

# %%
import json

with open(
    "results/benchmark_results.json",
    "r",
) as f:

    benchmark = json.load(f)

# %%
reporter = RobustnessReporter(
    benchmark
)

# %%
reporter.to_dataframe()

# %%
reporter.save_csv(
    "results/benchmark_table.csv"
)

# %%
reporter.plot_f1(
    "results/robustness_plot.png"
)
